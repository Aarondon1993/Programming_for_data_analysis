# %%
race= ['Caucasian', 'African', 'Asian', 'Other']

import numpy as np
x= np.random.choice(race, size= 100)

import pandas as pd
s=  {'Race': [x] }

d=pd.Series(index= [x]) 
d
y= np.random.randint(1,30, size= 100)
y
pd.DataFrame(y, index= x)

Gender = ['Male', 'Female']
z= np.random.choice(Gender, size= 100)

pd. DataFrame({'Race':x, 'Length of Sentence':y, 'Gender':z})
# Out:
#          Race  Length of Sentence  Gender
# 0     African                  22    Male
# 1   Caucasian                  18  Female
# 2     African                  21  Female
# 3     African                  11    Male
# 4       Asian                  20    Male
# ..        ...                 ...     ...
# 95  Caucasian                  29  Female
# 96    African                  28  Female
# 97    African                   8  Female
# 98  Caucasian                  10  Female
# 99      Asian                  25    Male
#
# [100 rows x 3 columns]
